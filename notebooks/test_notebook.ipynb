# %%
import pandas as pd
from os import path

# %%
print(os.getcwd())
os.chdir('/Users/spencerwillard/code/local/fraud_detection_project/')
print(os.getcwd())
# Out:
# /Users/spencerwillard/code/local/fraud_detection_project/data
# /Users/spencerwillard/code/local/fraud_detection_project

# %%
apps = pd.read_csv("data/raw/applications.csv")
outcomes = pd.read_csv("data/raw/outcomes.csv")

# %%
apps.head()
# Out:
#    application_id     application_date  identity_risk_score
# 0               1  2023-01-01 00:00:00                  102
# 1               2  2023-01-01 01:00:00                  435
# 2               3  2023-01-01 02:00:00                  860
# 3               4  2023-01-01 03:00:00                  270
# 4               5  2023-01-01 04:00:00                  106

# %%
outcomes.head()
# Out:
#    application_id  fraud account_status charged_off
# 0               1      0           open          no
# 1               2      0           open          no
# 2               3      1      prevented         yes
# 3               4      0           open          no
# 4               5      0           open          no

# %%
outcomes["fraud"].value_counts()
# Out:
# fraud
# 0    5936
# 1    4064
# Name: count, dtype: int64

# %%
outcomes["fraud"].mean()
# Out:
# np.float64(0.4064)
